# %% [markdown]
# # Mã giả & Lưu đồ giải thuật
#
# ### Lập trình
#
# Lập trình là gì?

# %% [markdown]
# Lập trình là đưa ra những câu lệnh để máy tính thực hiện.
#
# Đưa ra câu lệnh A, trước câu lệnh B thì câu lệnh A sẽ được thực hiện trước.

# %% [markdown]
# ### Thuật toán
#
# Thuật toán là gì?

# %% [markdown]
# Thuật toán là những câu lệnh được đưa ra để giải quyết một vấn đề nào đó.

# %% [markdown]
# ### Mã gỉả
#
# #### Khái niệm:
#
# Mã giả được viết với ngôn ngữ tự nhiên một thuật toán nào đó dùng để giải quyết một vấn đề lập trình.
#
# Mã giả được quy ước chung theo từng nơi làm việc.
#
# Ví dụ:
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Mã giả:</b>

# %% [raw]
# input (mon)
# if (mon con):
#     order (mon)
# else:
#     if (com suon con):
#         order (com suon)
#     else:
#         sleep

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Mã giả:</b>

# %% [raw]
# input (so)
# if (so > 10):
#     in (so)
# else:
#     in (so khong lon hon 10)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Mã giả:</b>

# %% [raw]
# input (so)
# if (so > 0):
#     in (so duong)
# else:
#     if (so <0):
#         in (so am)
#     else:
#         in (0)

# %% [markdown]
# ### Lưu đồ giải thuật
#
# Lưu đồ giải thuật là một thuật toán được biểu diễn với dạng lưu đồ
#
# Công cụ vẽ lưu đồ giải thuật: https://draw.io/
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-11-08%20at%208.40.22%20AM.png](attachment:Screen%20Shot%202022-11-08%20at%208.40.22%20AM.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-11-08%20at%208.44.01%20AM.png](attachment:Screen%20Shot%202022-11-08%20at%208.44.01%20AM.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-11-08%20at%208.45.17%20AM.png](attachment:Screen%20Shot%202022-11-08%20at%208.45.17%20AM.png)

# %% [markdown]
# ### Bài tập
#
# <b>Đề bài</b>
#
# Nhập vào nhiệt độ C, chuyển sang độ F rồi in ra màn hình
#
# <b>Mã giả:</b>

# %% [raw]
# input (a)
# b = (a * 9/5) + 32
# in (b)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-11-08%20at%208.49.36%20AM.png](attachment:Screen%20Shot%202022-11-08%20at%208.49.36%20AM.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương tháng này, nếu lương tháng này nhiều hơn 2 triệu thì trừ đi 10% thuế, nếu không thì không trừ.
#
# Hãy tính và in ra lương thực nhận được
#
# <b>Mã giả:</b>

# %% [raw]
# input (a)
# if (a > 2000000):
#     b = (a * 0.9)
#     in (luong nhan: b)
# else:
#     in (luong nhan: a)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-11-08%20at%208.55.38%20AM.png](attachment:Screen%20Shot%202022-11-08%20at%208.55.38%20AM.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương thực nhận được tháng này, nếu lương ít hơn 10 triệu, đưa hết cho vợ, nếu lương nhiều hơn 10 triệu, vợ cho 10% lương
#
# Hãy tính và in ra màn hình phần lương mình được nhận
#
# <b>Mã giả:</b>

# %% [raw]
# input (a)
# if (a < 10000000):
#     in (dua vo het)
# else:
#         b = a * 0.1
#         in (b)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-11-09%20at%2012.17.55%20AM.png](attachment:Screen%20Shot%202022-11-09%20at%2012.17.55%20AM.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào số điểm văn và điểm toán, tính và in ra điểm trung bình, nếu điểm trung bình lớn hơn 8 thì in ra dòng chữ Học sinh giỏi, ngược lại thì in ra dòng chữ Không phải học sinh giỏi
#
# <b>Mã giả:</b>

# %% [raw]
# input (a)
# input (b)
# c = (a+b)/2
# if (c >8):
#     in (Hoc sinh gioi)
# else:
#     in (Khong phai hoc sinh gioi)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-11-09%20at%2012.22.53%20AM.png](attachment:Screen%20Shot%202022-11-09%20at%2012.22.53%20AM.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra xem số đó có chia hết cho 5 hay không
#
# <b>Mã giả:</b>

# %% [raw]
# input (a)
# if (a%5)==0:
#     in (So chia het cho 5)
# else:
#     in (So khong chia het cho 5)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-11-09%20at%2012.25.43%20AM.png](attachment:Screen%20Shot%202022-11-09%20at%2012.25.43%20AM.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào điểm số, nếu điểm số lớn hơn hoặc bằng 8, in ra dòng chữ Học sinh giỏi, nếu điểm số bé hơn 8 và lớn hơn hoặc bằng 6, in ra dòng chữ chữ học sinh Khá, ngược lại in ra dòng chữ Học sinh trung bình
#
# <b>Mã giả:</b>

# %% [raw]
# input (a)
# if (a >= 8):
#     in (Hoc sinh gioi)
# else:
#     if (so >=6):
#         in (Hoc sinh kha)
#     else:
#         in (Hoc sinh trun binh)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-11-09%20at%2012.30.11%20AM.png](attachment:Screen%20Shot%202022-11-09%20at%2012.30.11%20AM.png)

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra tính chẳn lẻ và số đó có lớn hơn 10 hay không. (in ra 4 trường hợp: chẳn lớn hơn 10, lẻ lớn hơn 10, chẳn bé hơn hoặc bằng 10, lẻ bé hơn 10)
#
# <b>Mã giả:</b>

# %% [raw]
# input (a)
# if (a%2)==0:
#     if (a > 10):
#         in (So chan, lon hon 10)
#     else:
#         in (So chan, be hon hoac bang 10)
# else:
#     if (a > 10):
#         in (So le, lon hon 10)
#     else:
#         in (So le, be hon hoac bang 10)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![Screen%20Shot%202022-11-09%20at%2012.38.48%20AM.png](attachment:Screen%20Shot%202022-11-09%20at%2012.38.48%20AM.png)
